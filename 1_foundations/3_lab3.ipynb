# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr
import os

# %%
load_dotenv(override=True)

ollama_api_key = os.getenv('OLLAMA_API_KEY')
model=os.getenv('OLLAMA_MODEL')
ollama_base_url=os.getenv('OLLAMA_BASE_URL')


openai = OpenAI(base_url=ollama_base_url, api_key=ollama_api_key)

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# Hyderabad
# +91 9630747751 (Mobile)
# mrashutoshnigam@gmail.com
# www.linkedin.com/in/
# mrashutoshnigam (LinkedIn)
# www.mrashutoshnigam.in
# (Personal)
# visualbasic-dotnet-
# hindi.blogspot.in/ (Blog)
# www.mrashutoshnigam.in (Blog)
# Top Skills
# Extract, Transform, Load (ETL)
# Continuous Integration and
# Continuous Delivery (CI/CD)
# REST APIs
# Languages
# Hindi (Full Professional)
# English
# Certifications
# EssentialTECH Foundations
# AI for Everyone
# Learning to Build Alexa Skills
# The Elements of Effective
# Photographs
# Microsoft Certified: Azure
# Fundamentals
# Honors-Awards
# Best Student - BSc I.T.
# Best Student - 11th
# Best Student - 10th
# Best Student- 9th
# Best Student - 8th
# Publications
# Educational Blog
# Projects Blog
# Ashutosh Nigam
# Principal Software Engineer @ Blackbaud | Master of Technology
# in Artificial Intelligence | book a 1:1 with me at topmate.io/
# mrashutoshnigam
# Hyderabad, Telangana, India
# Summary
# I am a Principal Software Engineer at Blackbaud, where I design and
# deliver scalable, high-performance software that empowers nonprofit
# organizations to achieve greater impact. With prior experience as
# Lead Software Engineer at S&P Global, I bring expertise in cloud
# platforms, enterprise applications, and large-scale data pipelines. I
# am passionate about mentorship, fostering technical excellence, and
# exploring AI-driven solutions to address evolving business needs.
# Holding a Master’s in AI and Machine Learning, I actively contribute
# to building intelligent, efficient systems while collaborating with global
# teams. I enjoy connecting with professionals who share an interest in
# technology, leadership, and innovation.
# Experience
# Blackbaud
# Principal Software Engineer
# March 2025 - Present (10 months)
# Hyderabad, Telangana, India
# I am dedicated to advancing JustGiving's capabilities as a Principal Software
# Engineer at Blackbaud.
# • Developed and enhanced RESTful APIs, significantly improving donation
# workflows and user engagement.
# • Implemented performance optimizations that increased platform scalability
# and reliability.
# • Contributed to system modernization efforts, ensuring a seamless integration
# with third-party services.
# S&P Global
# 5 years 3 months
# Lead Software Engineer
# April 2024 - February 2025 (11 months)
# Hyderabad, Telangana, India
#   Page 1 of 4
# • Led a team of 8 to rearchitect the application into a serverless architecture,
# focusing on solution design, new development, code reviews, QA, and
# performance optimization.
# • Mentored team members in adopting new technologies to enhance their skills
# and guided them through project timelines and deliverables.
# • Oversaw successful design, implementation, and deployment of the
# application, ensuring high quality and performance.
# Senior Software Engineer
# February 2022 - March 2024 (2 years 2 months)
# Hyderabad, Telangana, India
# • Led research and development in the Platts Data Platform Division, focusing
# on data processing and API development.
# • Spearheaded projects like the Platts Data platform and REST Wrapper,
# emphasizing scalable pipelines and robust API design.
# • Mentored junior team members, engaged in technical discussions, and drove
# continuous improvement and innovation.
# Software Engineer
# December 2019 - January 2022 (2 years 2 months)
# Hyderabad Area, India
# • Collaborated with a talented team to design and implement data processing
# functionalities and APIs.
# • Contributed to projects like the Platts Data platform and EMRG, focusing on
# creating efficient data pipelines.
# • Actively participated in technical discussions, provided valuable insights, and
# remained updated on emerging technologies.
# NCR Corporation
# Software Engineer
# September 2015 - December 2019 (4 years 4 months)
# Hyderabad Area, India
# • Provided troubleshooting, debugging, and enhancement support for ACS
# Web-Office Solutions at NCR Corporation.
# • Developed new features, optimized performance, and ensured reliability and
# scalability of the application.
# • Actively participated in cross-functional collaboration, including code reviews
# and providing technical guidance.
# Threshold Software Solutions Pvt Ltd
# Software Developer
#   Page 2 of 4
# June 2014 - June 2015 (1 year 1 month)
# • Spearheaded the development of the Oasis web application for an
# International School, encompassing essential modules like CRM, CMS, and
# LMS.
# • Utilized technologies such as WCF services, MVC, jQuery, and MS SQL
# Server for both front-end and back-end development.
# • Translated requirements into a comprehensive web solution, ensuring
# seamless integration and functionality.
# NACRE
# Software Trainee
# August 2012 - December 2012 (5 months)
# • Actively participated in various software development initiatives at Nacre
# Software Services, gaining hands-on experience.
# • Learned programming languages and technologies under experienced
# mentors to enhance skills.
# • Contributed to real-time development projects, honing skills for a transition to
# a software developer role.
# Shri Sai Computer & I.T.
# Project Guide and Computer Faculty
# July 2009 - December 2011 (2 years 6 months)
# Rewa
# Led academic projects in C++, VB.NET, and ASP.NET at SSCIT Rewa,
# guiding students to apply theoretical knowledge practically. Fostered a
# supportive learning environment to excel in programming studies.
# • Instructed courses in Data Communications and Data Structure
# • Encouraged students to pursue their passion for programming
# Education
# Indian Institute of Technology Jodhpur
# Master of Technology - MTech, Artificial Intelligence · (January 2025 - March
# 2027)
# Amity University, Noida
# Master of Computer Applications - MCA, Machine Learning and Artificial
# Intelligence · (January 2022 - March 2024)
#   Page 3 of 4
# Makhanlal Chaturvedi Rashtriya Patrakarita Vishwavidhyalaya
# Bachelor of Science - BS, Information Technology · (2006 - 2009)
#   Page 4 of 4

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Ashutosh Nigam"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Ashutosh Nigam. You are answering questions on Ashutosh Nigam's website, particularly questions related to Ashutosh Nigam's career, background, skills and experience. Your responsibility is to represent Ashutosh Nigam for interactions on the website as faithfully as possible. You are given a summary of Ashutosh Nigam's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nI am a Principal Software Engineer at Blackbaud, where I design and deliver scalable, high-performance software that empowers nonprofit organizations to achieve greater impact. With prior experience as Lead Software Engineer at S&P Global, I bring expertise in cloud platforms, enterprise applications, and large-scale data pipelines. I am passionate about mentorship, fostering technical excellence, and exploring AI-driven solutions to address evolving business needs. Holding a Master’s in AI and Machine Learning, I actively contribute to building intelligent, efficient systems while collaborating with global teams. I enjoy connecting with professionals who share an interest in technology, leadership, and innovation.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nHyderabad\n+91 9630747751 (Mobile)\nmrashutoshnigam@gmail.com\nwww.linkedin.com/in/\nmrashutoshnigam (LinkedIn)\nwww.mrashutoshnigam.in\n(Personal)\nvisualbasic-dotnet-\nhindi.blogspot.in/ (Blog)\nwww.mrashutoshnigam.in (Blog)\nTop Skills\nExtract, Transform, Load (ETL)\nContinuous Integration and\nContinuous Delivery (CI/CD)\nREST APIs\nLanguages\nHindi (Full Professional)\nEnglish\nCertifications\nEssentialTECH Foundations\nAI for Everyone\nLearning to Build Alexa Skills\nThe Elements of Effective\nPhotographs\nMicrosoft Certified: Azure\nFundamentals\nHonors-Awards\nBest Student - BSc I.T.\nBest Student - 11th\nBest Student - 10th\nBest Student- 9th\nBest Student - 8th\nPublications\nEducational Blog\nProjects Blog\nAshutosh Nigam\nPrincipal Software Engineer @ Blackbaud | Master of Technology\nin Artificial Intelligence | book a 1:1 with me at topmate.io/\nmrashutoshnigam\nHyderabad, Telangana, India\nSummary\nI am a Principal Software Engineer at Blackbaud, where I design and\ndeliver scalable, high-performance software that empowers nonprofit\norganizations to achieve greater impact. With prior experience as\nLead Software Engineer at S&P Global, I bring expertise in cloud\nplatforms, enterprise applications, and large-scale data pipelines. I\nam passionate about mentorship, fostering technical excellence, and\nexploring AI-driven solutions to address evolving business needs.\nHolding a Master’s in AI and Machine Learning, I actively contribute\nto building intelligent, efficient systems while collaborating with global\nteams. I enjoy connecting with professionals who share an interest in\ntechnology, leadership, and innovation.\nExperience\nBlackbaud\nPrincipal Software Engineer\nMarch 2025\xa0-\xa0Present\xa0(10 months)\nHyderabad, Telangana, India\nI am dedicated to advancing JustGiving's capabilities as a Principal Software\nEngineer at Blackbaud.  \n• Developed and enhanced RESTful APIs, significantly improving donation\nworkflows and user engagement.  \n• Implemented performance optimizations that increased platform scalability\nand reliability.  \n• Contributed to system modernization efforts, ensuring a seamless integration\nwith third-party services.\nS&P Global\n5 years 3 months\nLead Software Engineer\nApril 2024\xa0-\xa0February 2025\xa0(11 months)\nHyderabad, Telangana, India\n\xa0 Page 1 of 4\xa0 \xa0\n• Led a team of 8 to rearchitect the application into a serverless architecture,\nfocusing on solution design, new development, code reviews, QA, and\nperformance optimization.\n• Mentored team members in adopting new technologies to enhance their skills\nand guided them through project ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model=model, messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply

# %%
evaluate(reply, "do you hold a patent?", messages[:1])

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
